# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/cached/pitch_archetype_clusters_2025_k8.parquet')
df1 = pd.read_parquet('../data/cached/pitch_archetype_offerings_2025_k8.parquet')

# %%
df1.head()
# Out:
#    season  pitcher_id pitch_hand pitch_type       pitch_name  pitches  \
# 0    2025      434378          R         CH         Changeup      222
# 1    2025      434378          R         CU        Curveball      381
# 2    2025      434378          R         FF  4-Seam Fastball     1181
# 3    2025      434378          R         SI           Sinker       10
# 4    2025      434378          R         SL           Slider      607
#
#    release_speed     pfx_x     pfx_z  release_spin_rate  release_extension  \
# 0      84.678829 -1.080000  0.780766        1728.734234           6.041441
# 1      78.470079  0.628504 -1.027428        2748.280840           5.996063
# 2      93.919983 -0.739526  1.552625        2434.988146           6.012532
# 3      93.270000 -0.993000  1.362000        2474.000000           6.030000
# 4      87.128830  0.337743  0.459934        2500.329489           6.019275
#
#    release_pos_x  release_pos_z pitch_family  pitch_archetype
# ...
